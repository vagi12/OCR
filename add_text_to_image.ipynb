# %%
from PIL import Image
from PIL import ImageDraw

img = Image.open("car.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=768x411>

# %%
draw = ImageDraw.Draw(img)

# %%
draw.text((40,80), "Its expensive", (255,0,0))

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=768x411>
