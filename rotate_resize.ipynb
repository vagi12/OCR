# %%
from PIL import Image

img = Image.open("car.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=768x411>

# %%
#rotate
r1 = img.rotate(90)

# %%
r1
# Out:
# <PIL.Image.Image image mode=RGBA size=768x411>

# %%
#resize
img.size
# Out:
# (768, 411)

# %%
size = (200,350)
r2 = img.resize(size)

# %%
r2
# Out:
# <PIL.Image.Image image mode=RGBA size=200x350>
