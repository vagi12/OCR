# %%
from PIL import Image

img = Image.open("car.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=768x411>

# %%
#cropping
img.size
# Out:
# (768, 411)

# %%
width, height = img.size

# %%
width
# Out:
# 768

# %%
height
# Out:
# 411

# %%
left = 5
top = height/5
right = 150
bottom = 3* height/5

# %%
crop = img.crop((left,top,right,bottom))

# %%
crop
# Out:
# <PIL.Image.Image image mode=RGBA size=145x165>
